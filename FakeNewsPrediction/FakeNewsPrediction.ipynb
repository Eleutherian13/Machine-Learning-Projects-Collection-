# %% [markdown]
# About the Dataset:
#
# 1. id: unique id for a news article
# 2. title: the title of a news article
# 3. author: author of the news article
# 4. text: the text of the article; could be incomplete
# 5. label: a label that marks whether the news article is real or fake:
#            1: Fake news
#            0: real News

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple/
# Requirement already satisfied: nltk in c:\users\manas\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\manas\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\manas\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\manas\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\manas\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\manas\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
